# %%
from google.colab import drive
drive.mount('/content/drive')
# !wget -q https://github.com/kmille36/Colab-Cloud-Gaming/raw/refs/heads/main/ColabSteam
# !chmod +x ColabSteam
# !./ColabSteam
# Out:
# Mounted at /content/drive
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 43.0 MB/s eta 0:00:00
# Colab GPU Gaming by fb.com/thuong.hai.581 v2.2.0 FIX-NETWORK-LAG. Sunshine, Steam, Heroic
# Preparing installation files. Please wait...
# Running: tailscale up
#
# To authenticate, visit:
#
# 	https://login.tailscale.com/a/464bab401a216
